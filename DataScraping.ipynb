# %% [markdown]
# <a href="https://colab.research.google.com/github/WilloIzCitron/ColabArchive/blob/main/DataScraping.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from bs4 import BeautifulSoup
import requests
import pandas

web = "https://genshin-impact.fandom.com/wiki/Character/List"
pg = requests.get(web)
res = BeautifulSoup(pg.content, "html.parser")
data = []
rows = res.find("tbody").find_all("tr")
for row in rows:
    cols = row.find_all(["td", "th"])
    cols = [col.text.strip() for col in cols]
    if cols:
        data.append(cols)


pd = pandas.DataFrame(data)
pd = pd.iloc[1:].reset_index(drop=True)
pd
# Out:
#    0                   1 2        3         4          5              6  \
# 0                 Albedo        Geo     Sword  Mondstadt    Medium Male
# 1              Alhaitham     Dendro     Sword     Sumeru      Tall Male
# 2                   Aloy       Cryo       Bow       None  Medium Female
# 3                  Amber       Pyro       Bow  Mondstadt  Medium Female
# 4           Arataki Itto        Geo  Claymore    Inazuma      Tall Male
# .. ..                ... ..     ...       ...        ...            ...
# 90                 Yelan      Hydro       Bow      Liyue    Tall Female
# 91               Yoimiya       Pyro       Bow    Inazuma  Medium Female
# 92     Yumemizuki Mizuki      Anemo  Catalyst    Inazuma
# 93               Yun Jin        Geo   Polearm      Liyue  Medium Female
# 94               Zhongli        Geo   Polearm      Liyue      Tall Male
#
#                      7    8
# 0    December 23, 2020  1.2
# 1     January 18, 2023  3.4
# 2   September 01, 2021  2.1
# ...

# %%
from matplotlib import pyplot as plt
import seaborn as sns
pd.groupby(8).size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
pd.groupby(6).size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
pd.groupby(5).size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
pd.groupby(4).size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
from matplotlib import pyplot as plt
import seaborn as sns
pd.groupby(3).size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
plt.gca().spines[['top', 'right',]].set_visible(False)
